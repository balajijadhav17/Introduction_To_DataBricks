-- %%
select category,avg(price) as Avg_Price,
min(price) as Minimum_Price,
max(price) as Maximum_Price,
sum(price) as Total_Price,
count(*)  as Total_of_each_category
from products_enr group by category;
