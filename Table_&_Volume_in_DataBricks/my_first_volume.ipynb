# %% [markdown]
# # **Volume**

# %% [markdown]
# ### method 1 for creating **volume**

# %%
# %sql
use catalog my_first_catalog;
use schema bronze;

# %%
# %sql
create volume bronze_volume;

# %% [markdown]
# ### method 2 for creating **volume**

# %%
# %sql
create volume my_first_catalog.bronze.bronze_volume2;

# %% [markdown]
# ### Data Accessing in **volume**

# %%
# %sql
select * from csv.`/Volumes/my_first_catalog/bronze/bronze_volume2/sales/fact_sales.csv`
