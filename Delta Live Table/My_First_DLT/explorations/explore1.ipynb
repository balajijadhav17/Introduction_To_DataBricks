# %%
# %sql
create table my_first_catalog.bronze.source
(
  product_id int,
  product_name string,
  processdare timestamp
  
);

# %%
# %sql
insert into my_first_catalog.bronze.source
values
(1,'honey',current_timestamp()),
(2,'milk',current_timestamp()),
(3,'wholewheatebread',current_timestamp()),
(4,"mint",current_timestamp());

# %%
# %sql
select * from my_first_catalog.bronze.source;

# %%
# %sql
ALTER TABLE my_first_catalog.bronze.source 
SET TBLPROPERTIES (
  'delta.columnMapping.mode' = 'name'
);

# %%
# %sql
alter table my_first_catalog.bronze.source
rename column processdare to process_date;

# %%
# %sql
select * from my_first_catalog.bronze.source;

# %%
# %sql
select * from my_first_catalog.dlt_schema.scd1_table;

# %%
# %sql
select * from my_first_catalog.dlt_schema.scd2_table;

# %%
# %sql
select * from my_first_catalog.dlt_schema.scd3_table;

# %%
# %sql
select * from my_first_catalog.silver.products_enr;
