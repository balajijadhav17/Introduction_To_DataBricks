# %%
help(spark.read)

# %% [markdown]
# # **Read CSV using Table**

# %%
df=spark.table("pysparkdb.spark_one.fact_sales")

# %%
display(df)

# %%
df=spark.table("pysparkdb.spark_one.ipl_2022")

# %%
display(df)

# %%
df.printSchema()
