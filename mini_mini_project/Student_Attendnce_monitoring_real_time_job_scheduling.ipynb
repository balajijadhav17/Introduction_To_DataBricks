# %% [markdown]
# # Student Attendence Details Tracking System Real Time Attendence

# %%
from pyspark.sql import SparkSession
# from pyspark.sql.functions type import StringType, IntegerType
from pyspark.sql.types import StructType, StructField,IntegerType, StringType
from pyspark.sql.functions import * 
import numpy as np


# Generate random numbers
roll_number = np.arange(1,79)

student_names = [
    "Aarav", "Aadhya", "Vivaan", "Diya", "Aditya", "Ananya", "Vihaan", "Aarohi",
    "Arjun", "Ira", "Sai", "Sara", "Reyansh", "Myra", "Mohammed", "Kiara",
    "Shivansh", "Saanvi", "Krishna", "Anika", "Dhruv", "Navya", "Kabir", "Prisha",
    "Atharv", "Riya", "Rohan", "Aarna", "Ayaan", "Ishita", "Aryan", "Sia",
    "Arnav", "Tara", "Ishaan", "Aarya", "Veer", "Mira", "Siddharth", "Zara",
    "Rudra", "Amaira", "Yash", "Avni", "Ritvik", "Pari", "Pranav", "Maya",
    "Aarush", "Meera", "Advik", "Anvi", "Kartik", "Kavya", "Ansh", "Vanya",
    "Shlok", "Suhana", "Daksh", "Aditi", "Shaurya", "Jhanvi", "Lakshay", "Tanvi",
    "Ranveer", "Bhavya", "Om", "Ishani", "Kian", "Nisha", "Neil", "Priya",
    "Vikram", "Shreya", "Samar", "Radhika", "Manav", "Leela", "Raj", "Neha"  
]

Gender = ["Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male"
          ,"Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male"
          ,"Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female"]

Attendence=np.random.choice(["PRESENT","ABSENT"],size=78)



n1_list = roll_number.tolist()
n2_list = Attendence.tolist()


# Create a list of tuples
# Create a list of tuples in the correct order
list1 = list(
    zip(
        n1_list,           # Roll_No
        student_names,     # Name_of_student
        n2_list,           # Attendence
        Gender
    )
)

# Define schema with data types
schema = StructType([
    StructField("Roll_No", IntegerType(), True),
    StructField("Name_of_student", StringType(), True),
    StructField("Attendence", StringType(), True),
    StructField("Gender", StringType(), True)
])

# Create a DataFrame
df = spark.createDataFrame(
    data=list1,
    schema=schema
)
display(
    df.groupBy("Attendence")
      .count()
      .withColumnRenamed("count", "Student")
      .withColumn("current_date", current_date())
      .withColumn("day", date_format(current_date(), "EEEE"))
)
# Out:
# Databricks visualization. Run in Databricks to view.
