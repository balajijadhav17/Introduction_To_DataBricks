# %% [markdown]
# # **DBUTILS**

# %%
dbutils.help()

# %% [markdown]
# # **fs**

# %%
dbutils.help("fs")

# %% [markdown]
# ## List the all files of **folder**

# %%
dbutils.fs.ls("/Volumes/my_first_catalog/bronze/bronze_volume2/customers/")

# %% [markdown]
# ## Creating a new folder in the **volume**

# %%
dbutils.fs.mkdirs("/Volumes/my_first_catalog/bronze/bronze_volume2/customers")

# %% [markdown]
# ## Copy one file into another **folder**

# %%
dbutils.fs.cp("/Volumes/my_first_catalog/bronze/bronze_volume2/sales/","/Volumes/my_first_catalog/bronze/bronze_volume2/customers/",True)

# %% [markdown]
# # **Remove** the file or folder or both

# %%
dbutils.fs.rm("/Volumes/my_first_catalog/bronze/bronze_volume2/customers/fact_sales.csv")

# %% [markdown]
# ## create a **file** in using dbutils.fs

# %%
dbutils.fs.put("/Volumes/my_first_catalog/bronze/bronze_volume2/customers/firstfile.text","This is my first file Hi DataBricks",True)

# %%
dbutils.fs.put("/Volumes/my_first_catalog/bronze/bronze_volume2/customers/test.py","print(Hello World)",True)

# %%
dbutils.fs.put("/Volumes/my_first_catalog/bronze/bronze_volume2/customers/csv_file.csv","a,b,c",True)

# %%
files=dbutils.fs.ls("/Volumes/my_first_catalog/bronze/bronze_volume2/customers/")

# %%
file_name=[i.name for i in files]
file_name

# %%
for i in file_name:
    dbutils.fs.rm(f"/Volumes/my_first_catalog/bronze/bronze_volume2/customers/{i}")

# %% [markdown]
# # **widgets**

# %%
dbutils.widgets.text("par1","")

# %%
dbutils.widgets.get("par1")
