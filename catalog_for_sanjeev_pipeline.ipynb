# %%
# %sql
CREATE CATALOG IF NOT EXISTS food_ops;
USE CATALOG food_ops;

CREATE SCHEMA IF NOT EXISTS ingestion;
USE SCHEMA ingestion;

CREATE VOLUME IF NOT EXISTS sanjeev_files;

CREATE TABLE IF NOT EXISTS food_ops.ingestion.sanjeev_recipes (
  recipe_name STRING,
  ingredients STRING,
  methods STRING,
  cuisines STRING,
  prep_time STRING,
  cook_time STRING,
  others STRING,
  source_url STRING,
  ingested_at TIMESTAMP
)
USING DELTA;

# %%
df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("/Volumes/food_ops/ingestion/sanjeev_files/sanjeevkapoor_pipeline/data/recipes.csv")

display(df)
