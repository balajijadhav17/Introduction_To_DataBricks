# %% [markdown]
# # Dynamic **Jobs**

# %%
dbutils.widgets.text("para1", "")

# %%
para1_value=dbutils.widgets.get("para1")
para1_value

# %%
var2=dbutils.jobs.taskValues.get("lookup","lookup_output", debugValue="default_value")
var2
