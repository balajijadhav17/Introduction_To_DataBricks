# %%
dbutils.widgets.text("folder_name","")
dbutils.widgets.text("parent_folder_name","")

# %%
folder_name=dbutils.widgets.get("folder_name")
parent_folder_name=dbutils.widgets.get("parent_folder_name")

# %%
print(parent_folder_name)

# %%
print(folder_name)

# %%
df=spark.read.format("csv")\
    .option("header", "true")\
    .option("inferSchema", "true")\
    .load(f"/Volumes/my_first_catalog/bronze/bronze_volume2/{folder_name}/")

# %%
df.write.format("delta")\
    .mode("overwrite")\
    .save(f"/Volumes/my_first_catalog/bronze/jobvolume/{parent_folder_name}/{folder_name}")

# %%
df1=spark.read.format("delta")\
    .option("header", "true")\
    .option("inferSchema", "true")\
    .load("/Volumes/my_first_catalog/bronze/jobvolume/raw/stores/")

# %%
display(df1)
