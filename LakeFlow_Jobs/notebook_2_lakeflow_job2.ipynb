# %%
# %sql
# create volume my_first_catalog.bronze.job_volumne2;

# %%
df = spark.read.format("csv") \
    .option("header", True) \
    .option("inferSchema", True) \
    .load("/Volumes/my_first_catalog/bronze/bronze_volume2/stores/")

# %%
df.write.format("delta")\
    .mode("overwrite")\
    .save("/Volumes/my_first_catalog/bronze/job_volumne2/raw/stores/")
