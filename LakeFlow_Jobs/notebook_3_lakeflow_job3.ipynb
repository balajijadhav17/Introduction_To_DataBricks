# %%
# %sql
# create volume my_first_catalog.bronze.jobvolume3;

# %%
df=spark.read.format("csv")\
    .option("header","true")\
    .option("inferSchema","true")\
    .load("/Volumes/my_first_catalog/bronze/bronze_volume2/stores/")

# %%
df.write.format("delta")\
    .mode("overwrite")\
    .save("/Volumes/my_first_catalog/bronze/jobvolume3/raw/stores")
