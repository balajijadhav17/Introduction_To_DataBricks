# %% [markdown]
# # **AutoLoader**

# %%
# %sql
create volume my_first_catalog.bronze.autoloader_volume

# %% [markdown]
# # Autoloader **Query**

# %%
df=spark.readStream.format("cloudFiles")\
  .option("cloudFiles.format","csv")\
  .option("cloudFiles.schemaLocation","/Volumes/my_first_catalog/bronze/autoloader_volume/destination/checkpoint/")\
  .option("cloudFiles.schemaEvolutionMode","rescue")\
  .load("/Volumes/my_first_catalog/bronze/autoloader_volume/raw/")

# %%
df.writeStream.format("delta")\
    .outputMode("append")\
    .option("checkpointLocation","/Volumes/my_first_catalog/bronze/autoloader_volume/destination/checkpoint/")\
    .trigger(once=True)\
    .start("/Volumes/my_first_catalog/bronze/autoloader_volume/destination/data/")

# %%
d=spark.read.format("delta")\
    .load("/Volumes/my_first_catalog/bronze/autoloader_volume/destination/data/")
display(d)
