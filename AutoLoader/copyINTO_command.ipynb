# %%
# %sql
select * from parquet. `/Volumes/my_first_catalog/bronze/autoloader_volume/copyinto/part-00000-tid-1800520145580676501-2fb00642-a896-4599-9957-2c7260f04aa7-132-1.c000.snappy.parquet`

# %%
# %sql
create table my_first_catalog.bronze.copyintotbl
(
  order_id int,
  order_date date,
  order_status string,
  customer_id int,
  order_amount double
)

# %%
spark.sql(
    """
    COPY INTO my_first_catalog.bronze.copyintotbl
    FROM '/Volumes/my_first_catalog/bronze/autoloader_volume/copyinto/'
    FILEFORMAT = PARQUET
    FORMAT_OPTIONS ('mergeSchema' = 'true')
    COPY_OPTIONS ('mergeSchema' = 'true')
    """
)

# %%
# %sql
select * from my_first_catalog.bronze.copyintotbl
