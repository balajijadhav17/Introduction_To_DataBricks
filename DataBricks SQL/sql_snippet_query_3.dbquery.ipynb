-- %%
-- static snappit
-- select * from products_enr
-- where category="Toys"

-- dynamic snappit

-- select * from products_enr
-- where category = "Clothing"

select * from products_enr
where category = "Books" AND price >= 100;
