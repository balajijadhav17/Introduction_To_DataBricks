-- %%
select * from products_enr
where category = :para_category;

select identifier(:para_col1),identifier(:para_col2) from products_enr; -- return the columns just you enter the name of columns :param_3
