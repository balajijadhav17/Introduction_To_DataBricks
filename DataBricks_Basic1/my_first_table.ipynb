# %% [markdown]
# # **Createing a Table in DataBricks**

# %%
# %sql
USE CATALOG my_first_catalog;

# %%
# %sql
USE SCHEMA bronze;

# %%
# %sql
CREATE TABLE sales_table (
    id INT,
    product STRING,
    amount DOUBLE,
    sale_date DATE
)
USING DELTA;

# %%
# %sql
use catalog my_first_catalog;
use schema bronze;

# %% [markdown]
# # dataset name is sales or table name is **sales**

# %%
# %sql
select * from sales;
