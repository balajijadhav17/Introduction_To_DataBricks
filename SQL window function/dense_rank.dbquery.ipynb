-- %%
select * from student;

select *,dense_rank() over(order by marks) as dense_rank_ranking from student;
select *,dense_rank() over(partition by branch order by marks desc) as ranking from student;

select *,rank() over(partition by branch order by marks desc) as rank ,
dense_rank() over(partition by branch order by marks desc) as dense_rank from student;
