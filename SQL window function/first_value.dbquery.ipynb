-- %%
select * from student;

select *,first_value(student_name) over(order by marks desc) as firstname from student;

select *,first_value(marks) over(order by marks desc) as lastvalue from student;



select *,first_value(student_name) over(partition by branch order by marks desc) as firstname from student;
